# %% [markdown]
# # main.ipynb
#
# \<< Short description >>
#
# Authors: Angelo D. Bonzanini, Giorgos Makrygiorgos, and Victor Miller \\
# (c) January 2021
#
# ## Requirements:
# * Add any particular modules that need to be installed
# * Add any files that need to be in the same folder (e.g., ResNet.ipynb)
# * Python version
# * etc.
#
# \<< Write some basic documentation here >>

# %% [markdown]
# ## Setting up the environment and importing modules
#
# * First, we import standard libraries such as matplotlib, numpy, etc. If a library (e.g., casadi) is not installed create a new cell and type:
# ```
# !pip install casadi
# ```
#
# * Because .ipynb files arenot .py files, we cannot readily import them as we would a .py file. Forunately, we can use the [import_ipynb](https://pypi.org/project/import-ipynb/) module to import .ipynb files. We just need to make sure that we change the directory to wherever the .ipynb file is located.
#
# * Note: if you are using Google colab, we need to make sure that we are installing the libraries on our Google drive folder. Otherwise, next time we open the notebook we will have to re-install the libraries. To circumvent this issue, we we first need to give access to the colab notebook to read the Google Drive (using ```drive.mount()```) and then use pip with a target, i.e.,
# ```
# !pip install --target=$path casadi
# ```

# %%
# Import libraries
import os, sys
import matplotlib.pyplot as plt
from casadi import *
import import_ipynb

# %%
# Import other Python notebooks
from neural_model_identification import *
# Out:
# importing Jupyter notebook from neural_model_identification.ipynb
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 5)]               0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 30
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 18
# =================================================================
# Total params: 108
# Trainable params: 108
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 160/160 [==============================] - 3s 19ms/step - loss: 0.0297 - val_loss: 0.0223
# Epoch 2/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0236 - val_loss: 0.0208
# Epoch 3/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0229 - val_loss: 0.0194
# Epoch 4/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0226 - val_loss: 0.0188
# Epoch 5/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0216 - val_loss: 0.0189
# Epoch 6/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0209 - val_loss: 0.0183
# Epoch 7/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0217 - val_loss: 0.0179
# Epoch 8/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0200 - val_loss: 0.0173
# Epoch 9/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0196 - val_loss: 0.0163
# Epoch 10/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0181 - val_loss: 0.0155
# Epoch 11/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0164 - val_loss: 0.0136
# Epoch 12/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0144 - val_loss: 0.0107
# Epoch 13/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0106 - val_loss: 0.0076
# Epoch 14/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0069 - val_loss: 0.0044
# Epoch 15/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0043 - val_loss: 0.0031
# Epoch 16/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 17/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 18/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 19/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 20/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 21/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 22/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 23/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 24/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 25/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 26/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 27/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 28/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 29/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 30/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 31/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 32/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 33/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 34/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 35/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 36/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 37/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 38/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 39/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 40/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 41/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 42/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 43/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 44/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 45/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 46/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 47/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 48/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 49/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 50/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 51/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 52/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 53/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 54/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 55/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 56/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 57/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 58/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 59/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 60/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 61/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 62/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 63/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 64/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 65/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 66/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 67/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 68/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 69/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 70/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 71/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 72/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 73/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 74/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 75/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 76/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 77/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 78/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 79/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 80/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 81/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 82/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 83/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 84/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 85/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 86/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 87/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 88/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 89/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 90/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 91/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 92/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 93/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 94/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 95/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 96/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 97/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 98/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 99/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 100/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 101/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 102/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 103/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 104/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 105/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 106/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 107/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 108/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 109/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 110/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 111/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 112/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 113/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 114/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 115/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 116/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 117/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 118/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 119/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 120/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 121/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 122/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 123/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 124/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 125/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 126/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 127/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 128/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 129/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 130/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 131/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 132/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 133/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 134/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 135/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 136/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 137/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 138/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 139/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 140/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 141/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 142/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 143/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 144/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 145/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 146/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 147/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 9
1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   {
# [0.29738612 0.01965556 0.00653503]
# [0.29738612 0.01965556 0.00653503]
# (5,)

# %% [markdown]
# ## Define a class that intializes all of the parameters and instantiate object

# %%
# Note that classes are conventionally defined with a capital first letter
class Parameters:
    # The __init__() function is like a constructor 
    #(can give it arguments if we want to intialize some parameters depending on how we instantiate the class)
    def __init__(self): 

        # Constants (conventionally with all-capitals)
        self.VIN = 1
        self.TSAMP = 0.005
        self.AREA = 0.002436 # reactor cross-sectional area (m^2)
        self.L = 1.06        # reactor length (m)
        

        # Neural Net parameters
        self.n_hidden_layers = 3 
        self.n_nodes = 5
        # self.weights
        # self.biases

        # Horizon lengths
        self.Np =  10     # Prediction horizon
        self.Nsim = 100   # Simulation horizon
        self.Nmc = 1      # Monte Carlo simulations (maybe we won't need this)

        # Cost matrices and variable sizes
        self.nx = 3
        self.nu = 2
        # If we had a tracking objective, we would define Q and R here, too 

        # Variable bounds (as a list, not a numpy array)
        self.xMin = [0.0]*self.nx
        self.xMax = [999]*self.nx
        self.uMin = [0.01, 0.0]
        self.uMax = [0.25, 0.9]

        # Initial state vectors (as a list, not a numpy array)
        zInit = model_data.get("Zin")
        xo = initial_cond_plant.get("yo")
        
        self.xInit = zInit[0,-3:].tolist()
        self.zInit = zInit[0,:].tolist()
        self.xAll = xo
        

p = Parameters()

# %% [markdown]
# ## Modify any functions that need to take CasADi variables as inputs
#
# Here, we redefine the ```predictive_model_resnet(z, W)``` function.

# %%
def predictive_model_resnet(zk,Wmat, p): 
    #Assuming you can pass extra arguments to the function for casadi, otherwsise
    #Number of hidden layers and nodes are given once when we get the optimal resnet
    #The Bayesian Optimization Loop will be changing 
    n_hidden_layers = p.n_hidden_layers
    n_nodes = p.n_nodes
    model_input = reshape(zk,1,p.nu+p.nx)
    Wmat_shape = Wmat.shape[0]
    
    #Initialize from input 
    sum0 = mtimes(model_input,Wmat[0]).T #Matrix multiplication weights*inputs
    sumbias0 = sum0 + Wmat[1] #Add bias to construct y = sum(wi*xi) + b
    #neuron_out = swish_eval(sum1bias)
    neuron_out = sumbias0/(1+exp(-sumbias0)) #explicitly writing swish activation, out = fact(y)
    #They are vector quantitites so you might need to change stuff a bit with symbolic vars
#     print(neuron_out.shape)

    #Forward prediction in hidden layers
    for k in range(n_hidden_layers-1):
        sum0 = mtimes(neuron_out.T,Wmat[2*k+2]).T
        sumbias0 = sum0 + Wmat[2*k+3]
        neuron_out = sumbias0/(1+exp(-sumbias0)) #explicitly writing swish activation

    #Final output layer with linear activation
    sum0 = mtimes(neuron_out.T,Wmat[Wmat_shape-2]).T
    sumbias0 = sum0 + Wmat[Wmat_shape-1]
    neuron_out = sumbias0  #linear activation

    return neuron_out.T #+ model_input[0,2:5]

# %%
# Define augmented state vector for PDE
xAll = p.xAll

# Define augmented vector of concatenated states and inputs
zk=np.array(p.zInit)
print('zk = ', zk)

# Evaluate neural net prediction 
xkplusone_neural = DropModel.predict(zk.reshape(1,-1))
print('x+ from DropModel = ', xkplusone_neural)
xkplusone = predictive_model_resnet(DM(zk),Wmat, p)
print('x+ from predictive_model_resnet = ', xkplusone)

# Evaluate plant model prediction
xkplusonePlant = plantDynamics(eng, xAll, zk.reshape(1,-1))
print('x+ plant = ', xkplusonePlant[0,-3:])
# Out:
# zk =  [0.11050563 0.6529952  0.3        0.         0.        ]
# x+ from DropModel =  [[ 2.9921997e-01 -2.9817689e-05 -6.7140069e-04]]
# x+ from predictive_model_resnet =  [[0.29922, -2.98323e-05, -0.000671402]]
# x+ plant =  [0.29738612 0.01965556 0.00653503]

# %% [markdown]
# Embed DropModel into a CasADi function
# (DO NOT USE - still in experimental stage)

# %%
'''
nd=4
class dropModelCasadi(Callback):
  def __init__(self, name,  opts={}):
    Callback.__init__(self)
    self.construct(name, opts)

  # Number of inputs and outputs
  def get_n_in(self): return 1
  def get_n_out(self): return 1
  
  def get_sparsity_in(self,i):
      return Sparsity.dense(1,len(zk))

  def get_sparsity_out(self,i):
      return Sparsity.dense(1,len(xk))

  # Evaluate numerically
  def eval(self, arg):
    out = DropModel.predict(np.array(arg[0]))
    return [out]


dropModelFn = dropModelCasadi('dropModelCasadi', {"enable_fd":True})

zz = MX.sym('zz', 1, 4)
print(zk)
xNNvar = dropModelFn(zz)
xNN2 = dropModelFn(zk.reshape(1,4))
print(xNN2)
print(xkplusone_neural) 
'''
# Out:
# '\nnd=4\nclass dropModelCasadi(Callback):\n  def __init__(self, name,  opts={}):\n    Callback.__init__(self)\n    self.construct(name, opts)\n\n  # Number of inputs and outputs\n  def get_n_in(self): return 1\n  def get_n_out(self): return 1\n  \n  def get_sparsity_in(self,i):\n      return Sparsity.dense(1,len(zk))\n\n  def get_sparsity_out(self,i):\n      return Sparsity.dense(1,len(xk))\n\n  # Evaluate numerically\n  def eval(self, arg):\n    out = DropModel.predict(np.array(arg[0]))\n    return [out]\n\n\ndropModelFn = dropModelCasadi(\'dropModelCasadi\', {"enable_fd":True})\n\nzz = MX.sym(\'zz\', 1, 4)\nprint(zk)\nxNNvar = dropModelFn(zz)\nxNN2 = dropModelFn(zk.reshape(1,4))\nprint(xNN2)\nprint(xkplusone_neural) \n'

# %% [markdown]
# ## Define variables, constraints, and functions
#
# Use classes to organize the code

# %% [markdown]
# # Objective Function
# Area = 0.002436;   % reactor cross-sectional area, m^2 \
# L = 1.06;   % reactor length, m  \
# Qmedia[j] = Area \times L \times Dk[j]  (Dk is u[0], i.e., dilution rate) \
# Try to maximize sum (Qmedia[j]*x1[j] ) (m3/h * mmol/m^3)  \
# Constraints:
# Selectivity is defined as Ce/Ca or x2/x1 and I want it to be x2/x1 < 0.45 \
# u[0] in (0.01, 0.25) \
# u[1] in (0.0, 0.9) \
# x0,x1,x2 > 0

# %%
class CasadiVars:
    def __init__(self, p):
        self.x = MX.sym("x", p.nx)
        self.u = MX.sym("u", p.nu)


class CasadiFunctions:
    def __init__(self, p, vars):
        # xNext = eulerPlantNext(vertcat(vars.u, vars.x))
        xNext = predictive_model_resnet(vertcat(vars.u, vars.x).T, Wmat, p).T
        Lstage = p.AREA * p.L * vars.u[0] * vars.x[1]
        self.dynamics = Function('dynamics', [vars.u, vars.x], [xNext], ['u', 'x'], ['xNext'])
        self.stageCost = Function('stageCost', [vars.u, vars.x], [Lstage], ['u', 'x'], ['Lstage'])

# class NonlinearConstraints:
#   # Define any additional constraints that cannot be expressed in the form xMin <= x <= xMax (not needed at the moment)
#   def __init__(self, x, p):
      # Use CasADi function syntax

class SaveTrajectory:
    def __init__(self, p):

        # Predicted variables
        self.xOptPred = np.zeros((p.nx, p.Np+1))
        self.uOptPred = np.zeros((p.nu, p.Np))

        # Real variables
        self.xOptReal = np.zeros((p.nx, p.Nsim+1))
        self.uOptReal = np.zeros((p.nu,p.Nsim))
        self.costFunctionReal = np.zeros((p.Nsim,1))

        # Assign initial conditions
        self.costFnReal = 0;
        self.xOptReal = np.zeros((p.nx,p.Nsim+1))
        self.xOptReal[:,0] = np.array(p.xInit).reshape(p.nx,)

# %% [markdown]
# ## Class that creates the optimal control problem (OCP)

# %%
class OptimalControlProblem:
    def __init__(self, Parameters, CasadiVars, CasadiFunctions):
        # Start with an empty NLP
        self.w=[]    #Array of all the variables we will be optimizing over
        self.w0 = []
        self.lbw = []
        self.ubw = []
        self.J = 0
        self.g=[]
        self.lbg = []
        self.ubg = []

        # "Lift" initial conditions
        Xk = MX.sym('X0', Parameters.nx)
        self.w += [Xk]
        self.lbw += Parameters.xInit
        self.ubw += Parameters.xInit
        self.w0  += Parameters.xInit

        for i in range(0, Parameters.Np):
            # New NLP variable for the control inputs
            Uk = MX.sym('U_' + str(i), Parameters.nu)
            self.w   += [Uk]
            self.lbw += Parameters.uMin
            self.ubw += Parameters.uMax
            self.w0  += Parameters.uMin

            # Integrate model and calculate stage cost
            xkNext = CasadiFunctions.dynamics(Uk, Xk)
            Zk = reshape(vertcat(Uk, Xk),1,Parameters.nu+Parameters.nx)
            # xkNext = reshape(CasadiFunctions.dropModel(Zk),Parameters.nx,1)
            JNext = CasadiFunctions.stageCost(Uk, Xk)
            self.J = self.J + JNext

            # New NLP variable for states at the next time-step
            Xk = MX.sym('X_' + str(i+1), Parameters.nx)
            self.w   += [Xk]
            self.lbw += Parameters.xMin
            self.ubw += Parameters.xMax
            self.w0  += [0]*Parameters.nx

            # Equality constraints (model dynamics)
            self.g   += [xkNext-Xk]
            self.lbg += [0]*Parameters.nx
            self.ubg += [0]*Parameters.nx
            
            # Inequality constraints (selectivity)
            self.g   += [Xk[2]-0.45*Xk[1]]
            self.lbg += [-inf]
            self.ubg += [0]

        # Terminal cost and constraints (if applicable)
        # N/A

        # Create NLP solver
        self.prob = {'f': self.J, 'x': vertcat(*self.w), 'g': vertcat(*self.g)}
        self.sol_opts = {'ipopt.print_level':1, 'ipopt.max_cpu_time':1.5, 'ipopt.hessian_approximation':'limited-memory'}
        self.solver = nlpsol('solver', 'ipopt', self.prob, self.sol_opts)    

        # Store variable dimensions for easy indexing
        self.offsetX0 = 0
        self.offsetU = Parameters.nx
        self.offsetOCP = Parameters.nx + Parameters.nu

# %%
# Create objects to instantiate the classes defined above
vars = CasadiVars(p)
s = SaveTrajectory(p)
fn = CasadiFunctions(p, vars)
# Create OCP object
OCP = OptimalControlProblem(p, vars, fn)

# Test (remove in the final version)
xNext1 = plantDynamics(eng, p.xAll, zk.reshape(1,-1))
xNext2 = fn.dynamics(DM(zk[0:2]), DM(zk[2:]))
print(zk)
print(xNext1[0,-3:])
print(xNext2)
print('Initial condition = ', p.xInit)
# Out:
# [0.11050563 0.6529952  0.3        0.         0.        ]
# [0.29738612 0.01965556 0.00653503]
# [0.29922, -2.98323e-05, -0.000671402]
# Initial condition =  [0.3, 0.0, 0.0]

# %%
print(OCP.lbw)
# Out:
# [0.3, 0.0, 0.0, 0.01, 0.0, 0.0, 0.0, 0.0, 0.01, 0.0, 0.0, 0.0, 0.0, 0.01, 0.0, 0.0, 0.0, 0.0, 0.01, 0.0, 0.0, 0.0, 0.0, 0.01, 0.0, 0.0, 0.0, 0.0, 0.01, 0.0, 0.0, 0.0, 0.0, 0.01, 0.0, 0.0, 0.0, 0.0, 0.01, 0.0, 0.0, 0.0, 0.0, 0.01, 0.0, 0.0, 0.0, 0.0, 0.01, 0.0, 0.0, 0.0, 0.0]

# %% [markdown]
# ## Closed-loop Simulation

# %%
# Set the initial condition and save the trajectory
xAll = p.xAll
x0Real = xAll[0,-3:]
s.xOptReal[:,0] = x0real

for k in range(0, p.Nsim):

    print("Iteration %i of %i" %(k+1, p.Nsim))

    # Update OCP constraints on initial state
    OCP.lbw[OCP.offsetX0:OCP.offsetX0+p.nx] = x0real
    OCP.ubw[OCP.offsetX0:OCP.offsetX0+p.nx] = x0real
    OCP.w0[OCP.offsetX0:OCP.offsetX0+p.nx] = x0real

    # Solve the NLP
    sol = OCP.solver(x0=OCP.w0, lbx=OCP.lbw, ubx=OCP.ubw, lbg=OCP.lbg, ubg=OCP.ubg)
    w_opt = sol['x'].full().flatten()
    J_opt = sol['f'].full().flatten()

    # Extract first optimal input
    uOpt = w_opt[OCP.offsetU:OCP.offsetOCP]

    # Plant model
    zReal = np.concatenate((uOpt, x0real))
    xAll = plantDynamics(eng, xAll, zReal.reshape(1,-1))
    x0real = xAll[0,-3:]
    # Save the trajectory
    s.uOptReal[:,k] = uOpt
    print(uOpt)
    s.xOptReal[:,k+1] = x0real + 0*np.random.normal(0, 1, size=(3, 1)).reshape(3,)

# print(s.uOptReal)
# print(s.xOptReal)
# Out:
# Iteration 1 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 825.00us (  5.69us) 832.00us (  5.74us)       145
#        nlp_g  |   3.49ms ( 24.05us)   3.51ms ( 24.21us)       145
#   nlp_grad_f  | 994.00us ( 12.58us)   1.03ms ( 13.01us)        79
#    nlp_jac_g  |  10.30ms ( 91.12us)  10.38ms ( 91.87us)       113
#        total  | 253.82ms (253.82ms) 253.71ms (253.71ms)         1
# [0.01218629 0.76257234]
# Iteration 2 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 594.00us (  4.87us) 603.00us (  4.94us)       122
#        nlp_g  |   2.47ms ( 20.24us)   2.54ms ( 20.81us)       122
#   nlp_grad_f  | 469.00us ( 10.42us) 474.00us ( 10.53us)        45
#    nlp_jac_g  |   6.31ms ( 85.23us)   6.34ms ( 85.68us)        74
#        total  | 154.99ms (154.99ms) 155.34ms (155.34ms)         1
# [0.01218659 0.76257192]
# Iteration 3 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.32ms (  5.71us)   1.38ms (  5.97us)       231
#        nlp_g  |   5.74ms ( 24.84us)   5.80ms ( 25.11us)       231
#   nlp_grad_f  |   1.74ms ( 11.43us)   1.76ms ( 11.61us)       152
#    nlp_jac_g  |  16.55ms ( 90.93us)  16.75ms ( 92.01us)       182
#        total  | 435.22ms (435.22ms) 436.59ms (436.59ms)         1
# [0.01       0.80389701]
# Iteration 4 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 874.00us (  5.91us) 906.00us (  6.12us)       148
#        nlp_g  |   3.70ms ( 25.01us)   3.76ms ( 25.43us)       148
#   nlp_grad_f  |   1.05ms ( 11.98us)   1.07ms ( 12.11us)        88
#    nlp_jac_g  |  11.29ms ( 92.52us)  11.43ms ( 93.66us)       122
#        total  | 262.66ms (262.66ms) 276.11ms (276.11ms)         1
# [0.01       0.84290978]
# Iteration 5 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |
of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 469.00us (  4.74us) 497.00us (  5.02us)        99
#        nlp_g  |   1.93ms ( 19.54us)   1.97ms ( 19.91us)        99
#   nlp_grad_f  | 881.00us (  9.47us) 907.00us (  9.75us)        93
#    nlp_jac_g  |   7.70ms ( 82.82us)   7.80ms ( 83.90us)        93
#        total  |  98.08ms ( 98.08ms)  98.42ms ( 98.42ms)         1
# [0.01000002 0.00014363]
# Iteration 88 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 143.00us (  5.30us) 140.00us (  5.19us)        27
#        nlp_g  | 573.00us ( 21.22us) 589.00us ( 21.81us)        27
#   nlp_grad_f  | 268.00us (  9.57us) 273.00us (  9.75us)        28
#    nlp_jac_g  |   2.29ms ( 81.96us)   2.30ms ( 82.00us)        28
#        total  |  38.82ms ( 38.82ms)  39.04ms ( 39.04ms)         1
# [0.01000002 0.00019293]
# Iteration 89 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 163.00us (  4.79us) 161.00us (  4.74us)        34
#        nlp_g  | 677.00us ( 19.91us) 680.00us ( 20.00us)        34
#   nlp_grad_f  | 326.00us (  9.31us) 325.00us (  9.29us)        35
#    nlp_jac_g  |   2.80ms ( 79.91us)   2.81ms ( 80.29us)        35
#        total  |  40.76ms ( 40.76ms)  40.82ms ( 40.82ms)         1
# [0.01000002 0.06273395]
# Iteration 90 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 188.00us (  4.95us) 189.00us (  4.97us)        38
#        nlp_g  | 778.00us ( 20.47us) 782.00us ( 20.58us)        38
#   nlp_grad_f  | 364.00us (  9.33us) 363.00us (  9.31us)        39
#    nlp_jac_g  |   3.24ms ( 83.03us)   3.26ms ( 83.69us)        39
#        total  |  46.61ms ( 46.61ms)  46.79ms ( 46.79ms)         1
# [0.01000002 0.01115327]
# Iteration 91 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 361.00us (  5.82us) 369.00us (  5.95us)        62
#        nlp_g  |   1.42ms ( 22.92us)   1.46ms ( 23.60us)        62
#   nlp_grad_f  | 612.00us (  9.87us) 629.00us ( 10.15us)        62
#    nlp_jac_g  |   5.28ms ( 85.11us)   5.32ms ( 85.87us)        62
#        total  |  75.05ms ( 75.05ms)  75.58ms ( 75.58ms)         1
# [0.01000002 0.00072895]
# Iteration 92 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 159.00us (  4.97us) 159.00us (  4.97us)        32
#        nlp_g  | 660.00us ( 20.62us) 664.00us ( 20.75us)        32
#   nlp_grad_f  | 322.00us (  9.76us) 324.00us (  9.82us)        33
#    nlp_jac_g  |   2.78ms ( 84.33us)   2.84ms ( 86.06us)        33
#        total  |  38.85ms ( 38.85ms)  39.18ms ( 39.18ms)         1
# [0.01000002 0.10824576]
# Iteration 93 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 167.00us (  5.22us) 164.00us (  5.13us)        32
#        nlp_g  | 680.00us ( 21.25us) 688.00us ( 21.50us)        32
#   nlp_grad_f  | 327.00us (  9.91us) 337.00us ( 10.21us)        33
#    nlp_jac_g  |   2.77ms ( 84.09us)   2.81ms ( 85.27us)        33
#        total  |  38.80ms ( 38.80ms)  38.97ms ( 38.97ms)         1
# [0.01000002 0.11463182]
# Iteration 94 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 155.00us (  4.84us) 155.00us (  4.84us)        32
#        nlp_g  | 639.00us ( 19.97us) 665.00us ( 20.78us)        32
#   nlp_grad_f  | 303.00us (  9.18us) 304.00us (  9.21us)        33
#    nlp_jac_g  |   2.66ms ( 80.64us)   2.69ms ( 81.42us)        33
#        total  |  37.32ms ( 37.32ms)  37.50ms ( 37.50ms)         1
# [0.01000002 0.11747755]
# Iteration 95 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 167.00us (  5.22us) 163.00us (  5.09us)        32
#        nlp_g  | 735.00us ( 22.97us) 734.00us ( 22.94us)        32
#   nlp_grad_f  | 347.00us ( 10.52us) 340.00us ( 10.30us)        33
#    nlp_jac_g  |   2.75ms ( 83.30us)   2.78ms ( 84.15us)        33
#        total  |  39.58ms ( 39.58ms)  40.25ms ( 40.25ms)         1
# [0.01000002 0.11482119]
# Iteration 96 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 157.00us (  4.91us) 160.00us (  5.00us)        32
#        nlp_g  | 719.00us ( 22.47us) 726.00us ( 22.69us)        32
#   nlp_grad_f  | 336.00us ( 10.18us) 335.00us ( 10.15us)        33
#    nlp_jac_g  |   2.74ms ( 83.03us)   2.74ms ( 83.06us)        33
#        total  |  38.26ms ( 38.26ms)  38.38ms ( 38.38ms)         1
# [0.01000002 0.11924671]
# Iteration 97 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 159.00us (  4.97us) 160.00us (  5.00us)        32
#        nlp_g  | 685.00us ( 21.41us) 692.00us ( 21.62us)        32
#   nlp_grad_f  | 335.00us ( 10.15us) 346.00us ( 10.48us)        33
#    nlp_jac_g  |   2.69ms ( 81.64us)   2.70ms ( 81.91us)        33
#        total  |  39.00ms ( 39.00ms)  39.15ms ( 39.15ms)         1
# [0.01000002 0.12092324]
# Iteration 98 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 162.00us (  5.06us) 163.00us (  5.09us)        32
#        nlp_g  | 683.00us ( 21.34us) 686.00us ( 21.44us)        32
#   nlp_grad_f  | 347.00us ( 10.52us) 356.00us ( 10.79us)        33
#    nlp_jac_g  |   2.75ms ( 83.21us)   2.78ms ( 84.15us)        33
#        total  |  38.37ms ( 38.37ms)  38.55ms ( 38.55ms)         1
# [0.01000002 0.12821967]
# Iteration 99 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 205.00us (  5.26us) 202.00us (  5.18us)        39
#        nlp_g  | 731.00us ( 18.74us) 749.00us ( 19.21us)        39
#   nlp_grad_f  | 372.00us (  9.30us) 377.00us (  9.42us)        40
#    nlp_jac_g  |   3.25ms ( 81.15us)   3.27ms ( 81.85us)        40
#        total  |  44.54ms ( 44.54ms)  44.66ms ( 44.66ms)         1
# [0.01000002 0.08069079]
# Iteration 100 of 100
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 218.00us (  4.74us) 229.00us (  4.98us)        46
#        nlp_g  | 943.00us ( 20.50us) 946.00us ( 20.57us)        46
#   nlp_grad_f  | 443.00us (  9.43us) 450.00us (  9.57us)        47
#    nlp_jac_g  |   3.84ms ( 81.81us)   3.89ms ( 82.83us)        47
#        total  |  56.08ms ( 56.08ms)  56.24ms ( 56.24ms)         1
# [0.01000002 0.38171608]

# %% [markdown]
# ## Plot Trajectories

# %%
# %matplotlib notebook
plt.figure()
plt.plot(s.xOptReal[0,:])
plt.plot(s.xOptReal[1,:])
plt.plot(s.xOptReal[2,:])
plt.xlabel('Time Step')
plt.ylabel('States')
plt.show()

plt.figure()
plt.step(range(0,p.Nsim), s.uOptReal[0,:])
plt.step(range(0,p.Nsim), s.uOptReal[1,:])
plt.xlabel('Time Step')
plt.ylabel('Input')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="713">
# <img src="data:image/png;base64,..." width="640">
