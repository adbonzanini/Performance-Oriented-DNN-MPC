# %% [markdown]
# Neural Model Identification: \
# Trains a neural network based on data from the physics model to use as the predictive model
# Note: You need to install the matlab engine to be able to run matlab code from pythone

# %%
import matplotlib.pyplot as plt

# %%
import os
import pickle
import math
#from utils import kits
import time
import random 
import numpy as np
import tensorflow as tf
import scipy.io
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.backend import sigmoid
from tensorflow.keras.utils import get_custom_objects
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Activation
from tensorflow.keras import backend as K
from tensorflow.python.framework import ops
#from skopt.utils import use_named_args
#from skopt import gp_minimize
#from skopt.space import Real, Categorical, Integer
from sklearn import preprocessing

# %%
import matlab.engine
eng = matlab.engine.start_matlab()

# %%
import scipy.io
model_data = scipy.io.loadmat('Data.mat')

# %%
Zin=model_data.get("Zin")
Zout=model_data.get("Zout")

# %% [markdown]
# ## Define Functions

# %%
def swish(x, beta=1):
    return x * sigmoid(beta * x)

def get_model_layers(nodes, layers, activation, learning_rate, training=None):
    if activation == 'swish':
        activation = swish
    else:
        activation = activation

    inputs = tf.keras.layers.Input(shape=(in_dim,))
  #  xadd = (np.array(inputs[:, :out_dim])).reshape(None,1)
   # print(inputs[:, :out_dim].shape)
    #print(xadd.shape)
    x = tf.keras.layers.Dense(units=nodes, activation=activation)(inputs)
    for i in range(layers - 1):  # at least one layer which has the parameter input as input
        x = tf.keras.layers.Dense(units=nodes, activation=activation)(x)

    #x = tf.keras.layers.Dropout(rate=0.1)(x, training=training)
    outputs = tf.keras.layers.Dense(out_dim, activation="linear")(x)
   # outputs = tf.keras.layers.Add()([outputs, inputs[:, 2:]])

    #outputs = tf.keras.layers.Add()([outputs, inputs[:, :out_dim]])
    # outputs = tf.keras.layers.Add()([outputs, inputs[:, :out_dim]]) NN4UQ
    #    out = keras.layers.Dense(units=3, activation= "linear")(added)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    optimizer = optimizers.Adagrad(lr=learning_rate)# amsgrad=True)
    model.compile(optimizer=optimizer,
                  loss='mean_absolute_error')
    return model

# %%
get_custom_objects().update({'swish': Activation(swish)})

# %%
X_train, X_test, Y_train, Y_test = train_test_split(Zin, Zout, shuffle=True, train_size=0.8, random_state=42)
in_dim = X_train.shape[1]
out_dim = Y_train.shape[1]

# %%
learning_rate=0.05#gp_result.x[0]
num_layers = 3 #gp_result.x[1]
num_nodes = 5 #gp_result.x[2]
batch_size=10 #gp_result.x[3]
epochs=300
activation='swish'
DropModel = get_model_layers(nodes=num_nodes, layers=num_layers,
                             activation=activation, learning_rate=learning_rate,
                             training=True)  # True-activates dropout during prediction
DropModel.summary()
DropModel.fit(X_train, Y_train,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (X_test, Y_test))

DetModel = get_model_layers(nodes=num_nodes, layers=num_layers,
                            activation=activation, learning_rate=learning_rate)
#name = '{}_{}_{}_{}'.format(num_nodes, num_layers, activation, learning_rate)
#DropModel.save(root + 'results/nc/' + name)
DetModel.set_weights(DropModel.get_weights())
score = DetModel.evaluate(X_test, Y_test, verbose=0)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 5)]               0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 30
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 18
# =================================================================
# Total params: 108
# Trainable params: 108
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0354 - val_loss: 0.0228
# Epoch 2/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0253 - val_loss: 0.0214
# Epoch 3/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0232 - val_loss: 0.0220
# Epoch 4/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0223 - val_loss: 0.0202
# Epoch 5/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0231 - val_loss: 0.0203
# Epoch 6/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0223 - val_loss: 0.0194
# Epoch 7/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0223 - val_loss: 0.0197
# Epoch 8/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0223 - val_loss: 0.0190
# Epoch 9/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0218 - val_loss: 0.0193
# Epoch 10/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0213 - val_loss: 0.0189
# Epoch 11/300
# 160/160 [==============================] - 0s 983us/step - loss: 0.0226 - val_loss: 0.0184
# Epoch 12/300
# 160/160 [==============================] - 0s 896us/step - loss: 0.0217 - val_loss: 0.0186
# Epoch 13/300
# 160/160 [==============================] - 0s 989us/step - loss: 0.0208 - val_loss: 0.0184
# Epoch 14/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0208 - val_loss: 0.0181
# Epoch 15/300
# 160/160 [==============================] - 0s 883us/step - loss: 0.0202 - val_loss: 0.0171
# Epoch 16/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0191 - val_loss: 0.0161
# Epoch 17/300
# 160/160 [==============================] - 0s 889us/step - loss: 0.0186 - val_loss: 0.0151
# Epoch 18/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0158 - val_loss: 0.0129
# Epoch 19/300
# 160/160 [==============================] - 0s 855us/step - loss: 0.0133 - val_loss: 0.0072
# Epoch 20/300
# 160/160 [==============================] - 0s 799us/step - loss: 0.0068 - val_loss: 0.0052
# Epoch 21/300
# 160/160 [==============================] - 0s 782us/step - loss: 0.0039 - val_loss: 0.0023
# Epoch 22/300
# 160/160 [==============================] - 0s 797us/step - loss: 0.0035 - val_loss: 0.0032
# Epoch 23/300
# 160/160 [==============================] - 0s 823us/step - loss: 0.0033 - val_loss: 0.0023
# Epoch 24/300
# 160/160 [==============================] - 0s 799us/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 25/300
# 160/160 [==============================] - 0s 869us/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 26/300
# 160/160 [==============================] - 0s 773us/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 27/300
# 160/160 [==============================] - 0s 810us/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 28/300
# 160/160 [==============================] - 0s 814us/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 29/300
# 160/160 [==============================] - 0s 789us/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 30/300
# 160/160 [==============================] - 0s 770us/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 31/300
# 160/160 [==============================] - 0s 867us/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 32/300
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 33/300
# 160/160 [==============================] - 0s 758us/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 34/300
# 160/160 [==============================] - 0s 772us/step - loss: 0.0025 - val_loss: 0.0032
# Epoch 35/300
# 160/160 [==============================] - 0s 815us/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 36/300
# 160/160 [==============================] - 0s 932us/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 37/300
# 160/160 [==============================] - 0s 810us/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 38/300
# 160/160 [==============================] - 0s 787us/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 39/300
# 160/160 [==============================] - 0s 947us/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 40/300
# 160/160 [==============================] - 0s 858us/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 41/300
# 160/160 [==============================] - 0s 766us/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 42/300
# 160/160 [==============================] - 0s 743us/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 43/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 44/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 45/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 46/300
# 160/160 [==============================] - 0s 917us/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 47/300
# 160/160 [==============================] - 0s 887us/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 48/300
# 160/160 [==============================] - 0s 906us/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 49/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 50/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 51/300
# 160/160 [==============================] - 0s 997us/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 52/300
# 160/160 [==============================] - 0s 929us/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 53/300
# 160/160 [==============================] - 0s 887us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 54/300
# 160/160 [==============================] - 0s 846us/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 55/300
# 160/160 [==============================] - 0s 895us/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 56/300
# 160/160 [==============================] - 0s 952us/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 57/300
# 160/160 [==============================] - 0s 813us/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 58/300
# 160/160 [==============================] - 0s 802us/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 59/300
# 160/160 [==============================] - 0s 807us/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 60/300
# 160/160 [==============================] - 0s 815us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 61/300
# 160/160 [==============================] - 0s 882us/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 62/300
# 160/160 [==============================] - 0s 816us/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 63/300
# 160/160 [==============================] - 0s 810us/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 64/300
# 160/160 [==============================] - 0s 827us/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 65/300
# 160/160 [==============================] - 0s 874us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 66/300
# 160/160 [==============================] - 0s 807us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 67/300
# 160/160 [==============================] - 0s 799us/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 68/300
# 160/160 [==============================] - 0s 799us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 69/300
# 160/160 [==============================] - 0s 764us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 70/300
# 160/160 [==============================] - 0s 771us/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 71/300
# 160/160 [==============================] - 0s 785us/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 72/300
# 160/160 [==============================] - 0s 795us/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 73/300
# 160/160 [==============================] - 0s 794us/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 74/300
# 160/160 [==============================] - 0s 729us/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 75/300
# 160/160 [==============================] - 0s 754us/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 76/300
# 160/160 [==============================] - 0s 764us/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 77/300
# 160/160 [==============================] - 0s 790us/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 78/300
# 160/160 [==============================] - 0s 748us/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 79/300
# 160/160 [==============================] - 0s 733us/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 80/300
# 160/160 [==============================] - 0s 738us/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 81/300
# 160/160 [==============================] - 0s 754us/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 82/300
# 160/160 [==============================] - 0s 837us/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 83/300
# 160/160 [==============================] - 0s 903us/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 84/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 85/300
# 160/160 [==============================] - 0s 838us/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 86/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 87/300
# 160/160 [==============================] - 0s 788us/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 88/300
# 160/160 [==============================] - 0s 753us/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 89/300
# 160/160 [==============================] - 0s 791us/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 90/300
# 160/160 [==============================] - 0s 870us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 91/300
# 160/160 [==============================] - 0s 783us/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 92/300
# 160/160 [==============================] - 0s 796us/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 93/300
# 160/160 [==============================] - 0s 750us/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 94/300
# 160/160 [==============================] - 0s 783us/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 95/300
# 160/160 [==============================] - 0s 834us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 96/300
# 160/160 [==============================] - 0s 846us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 97/300
# 160/160 [==============================] - 0s 751us/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 98/300
# 160/160 [==============================] - 0s 747us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 99/300
# 160/160 [==============================] - 0s 760us/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 100/300
# 160/160 [==============================] - 0s 765us/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 101/300
# 160/160 [==============================] - 0s 799us/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 102/300
# 160/160 [==============================] - 0s 805us/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 103/300
# 160/160 [==============================] - 0s 962us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 104/300
# 160/160 [==============================] - 0s 765us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 105/300
# 160/160 [==============================] - 0s 848us/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 106/300
# 160/160 [==============================] - 0s 771us/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 107/300
# 160/160 [==============================] - 0s 791us/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 108/300
# 160/160 [==============================] - 0s 833us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 109/300
# 160/160 [==============================] - 0s 804us/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 110/300
# 160/160 [==============================] - 0s 787us/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 111/300
# 160/160 [==============================] - 0s 781us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 112/300
# 160/160 [==============================] - 0s 766us/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 113/300
# 160/160 [==============================] - 0s 786us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 114/300
# 160/160 [==============================] - 0s 768us/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 115/300
# 160/160 [==============================] - 0s 771us/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 116/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 117/300
# 160/160 [==============================] - 0s 754us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 118/300
# 160/160 [==============================] - 0s 753us/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 119/300
# 160/160 [==============================] - 0s 730us/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 120/300
# 160/160 [==============================] - 0s 760us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 121/300
# 160/160 [==============================] - 0s 742us/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 122/300
# 160/160 [==============================] - 0s 747us/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 123/300
# 160/160 [==============================] - 0s 741us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 124/300
# 160/160 [==============================] - 0s 759us/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 125/300
# 160/160 [==============================] - 0s 764us/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 126/300
# 160/160 [==============================] - 0s 767us/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 127/300
# 160/160 [==============================] - 0s 747us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 128/300
# 160/160 [==============================] - 0s 743us/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 129/300
# 160/160 [==============================] - 0s 726us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 130/300
# 160/160 [==============================] - 0s 742us/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 131/300
# 160/160 [==============================] - 0s 755us/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 132/300
# 160/160 [==============================] - 0s 755us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 133/300
# 160/160 [==============================] - 0s 775us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 134/300
# 160/160 [==============================] - 0s 755us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 135/300
# 160/160 [==============================] - 0s 755us/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 136/300
# 160/160 [==============================] - 0s 740us/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 137/300
# 160/160 [==============================] - 0s 823us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 138/300
# 160/160 [==============================] - 0s 740us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 139/300
# 160/160 [==============================] - 0s 778us/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 140/300
# 160/160 [==============================] - 0s 750us/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 141/300
# 160/160 [==============================] - 0s 763us/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 142/300
# 160/160 [==============================] - 0s 762us/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 143/300
# 160/160 [==============================] - 0s 766us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 144/300
# 160/160 [==============================] - 0s 790us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 145/300
# 160/160 [==============================] - 0s 750us/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 146/300
# 160/160 [==============================] - 0s 742us/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 147/300
# 160/160 [==============================] - 0s 772us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 148/300
# 160/160 [==============================] - 0s 747us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 149/300
# 160/160 [==============================] - 0s 783us/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 150/300
# 160/160 [==============================] - 0s 759us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 151/300
# 160/160 [==============================] - 0s 787us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 152/300
# 160/160 [==============================] - 0s 769us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 153/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 154/300
# 160/160 [==============================] - 0s 787us/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 155/300
# 160/160 [==============================] - 0s 777us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 156/300
# 160/160 [==============================] - 0s 764us/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 157/300
# 160/160 [==============================] - 0s 824us/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 158/300
# 160/160 [==============================] - 0s 834us/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 159/300
# 160/160 [==============================] - 0s 815us/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 160/300
# 160/160 [==============================] - 0s 763us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 161/300
# 160/160 [==============================] - 0s 791us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 162/300
# 160/160 [==============================] - 0s 798us/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 163/300
# 160/160 [==============================] - 0s 803us/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 164/300
# 160/160 [==============================] - 0s 763us/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 165/300
# 160/160 [==============================] - 0s 730us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 166/300
# 160/160 [==============================] - 0s 757us/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 167/300
# 160/160 [==============================] - 0s 786us/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 168/300
# 160/160 [==============================] - 0s 844us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 169/300
# 160/160 [==============================] - 0s 986us/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 170/300
# 160/160 [==============================] - 0s 801us/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 171/300
# 160/160 [==============================] - 0s 874us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 172/300
# 160/160 [==============================] - 0s 811us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 173/300
# 160/160 [==============================] - 0s 782us/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 174/300
# 160/160 [==============================] - 0s 799us/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 175/300
# 160/160 [==============================] - 0s 832us/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 176/300
# 160/160 [==============================] - 0s 744us/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 177/300
# 160/160 [==============================] - 0s 814us/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 178/300
# 160/160 [==============================] - 0s 859us/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 179/300
# 160/160 [==============================] - 0s 765us/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 180/300
# 160/160 [==============================] - 0s 740us/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 181/300
# 160/160 [==============================] - 0s 734us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 182/300
# 160/160 [==============================] - 0s 808us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 183/300
# 160/160 [==============================] - 0s 839us/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 184/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 185/300
# 160/160 [==============================] - 0s 944us/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 186/300
# 160/160 [==============================] - 0s 837us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 187/300
# 160/160 [==============================] - 0s 745us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 188/300
# 160/160 [==============================] - 0s 748us/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 189/300
# 160/160 [==============================] - 0s 777us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 190/300
# 160/160 [==============================] - 0s 865us/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 191/300
# 160/160 [==============================] - 0s 822us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 192/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 193/300
# 160/160 [==============================] - 0s 759us/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 194/300
# 160/160 [==============================] - 0s 758us/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 195/300
# 160/160 [==============================] - 0s 771us/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 196/300
# 160/160 [==============================] - 0s 762us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 197/300
# 160/160 [==============================] - 0s 883us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 198/300
# 160/160 [==============================] - 0s 779us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 199/300
# 160/160 [==============================] - 0s 783us/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 200/300
# 160/160 [==============================] - 0s 764us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 201/300
# 160/160 [==============================] - 0s 750us/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 202/300
# 160/160 [==============================] - 0s 782us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 203/300
# 160/160 [==============================] - 0s 737us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 204/300
# 160/160 [==============================] - 0s 736us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 205/300
# 160/160 [==============================] - 0s 743us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 206/300
# 160/160 [==============================] - 0s 772us/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 207/300
# 160/160 [==============================] - 0s 821us/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 208/300
# 160/160 [==============================] - 0s 818us/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 209/300
# 160/160 [==============================] - 0s 819us/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 210/300
# 160/160 [==============================] - 0s 900us/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 211/300
# 160/160 [==============================] - 0s 768us/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 212/300
# 160/160 [==============================] - 0s 817us/step - loss: 0.0012 - val_loss: 9.8729e-04
# Epoch 213/300
# 160/160 [==============================] - 0s 795us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 214/300
# 160/160 [==============================] - 0s 751us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 215/300
# 160/160 [==============================] - 0s 756us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 216/300
# 160/160 [==============================] - 0s 772us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 217/300
# 160/160 [==============================] - 0s 758us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 218/300
# 160/160 [==============================] - 0s 732us/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 219/300
# 160/160 [==============================] - 0s 760us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 220/300
# 160/160 [==============================] - 0s 758us/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 221/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 9.9273e-04
# Epoch 222/300
# 160/160 [==============================] - 0s 734us/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 223/300
# 160/160 [==============================] - 0s 754us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 224/300
# 160/160 [==============================] - 0s 753us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 225/300
# 160/160 [==============================] - 0s 742us/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 226/300
# 160/160 [==============================] - 0s 758us/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 227/300
# 160/160 [==============================] - 0s 917us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 228/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 229/300
# 160/160 [==============================] - 0s 838us/step - loss: 0.0011 - val_loss: 9.7161e-04
# Epoch 230/300
# 160/160 [==============================] - 0s 773us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 231/300
# 160/160 [==============================] - 0s 824us/step - loss: 0.0011 - val_loss: 9.5229e-04
# Epoch 232/300
# 160/160 [==============================] - 0s 794us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 233/300
# 160/160 [==============================] - 0s 874us/step - loss: 0.0011 - val_loss: 9.8227e-04
# Epoch 234/300
# 160/160 [==============================] - 0s 754us/step - loss: 0.0011 - val_loss: 9.6802e-04
# Epoch 235/300
# 160/160 [==============================] - 0s 749us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 236/300
# 160/160 [==============================] - 0s 730us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 237/300
# 160/160 [==============================] - 0s 745us/step - loss: 0.0011 - val_loss: 9.5000e-04
# Epoch 238/300
# 160/160 [==============================] - 0s 776us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 239/300
# 160/160 [==============================] - 0s 769us/step - loss: 0.0011 - val_loss: 9.6870e-04
# Epoch 240/300
# 160/160 [==============================] - 0s 760us/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 241/300
# 160/160 [==============================] - 0s 744us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 242/300
# 160/160 [==============================] - 0s 743us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 243/300
# 160/160 [==============================] - 0s 768us/step - loss: 0.0011 - val_loss: 9.3586e-04
# Epoch 244/300
# 160/160 [==============================] - 0s 742us/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 245/300
# 160/160 [==============================] - 0s 818us/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 246/300
# 160/160 [==============================] - 0s 783us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 247/300
# 160/160 [==============================] - 0s 766us/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 248/300
# 160/160 [==============================] - 0s 756us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 249/300
# 160/160 [==============================] - 0s 751us/step - loss: 0.0011 - val_loss: 9.5174e-04
# Epoch 250/300
# 160/160 [==============================] - 0s 736us/step - loss: 0.0011 - val_loss: 9.7301e-04
# Epoch 251/300
# 160/160 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 9.1027e-04
# Epoch 252/300
# 160/160 [==============================] - 0s 723us/step - loss: 0.0011 - val_loss: 9.0828e-04
# Epoch 253/300
# 160/160 [==============================] - 0s 776us/step - loss: 0.0011 - val_loss: 9.4138e-04
# Epoch 254/300
# 160/160 [==============================] - 0s 759us/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 255/300
# 160/160 [==============================] - 0s 739us/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 256/300
# 160/160 [==============================] - 0s 769us/step - loss: 0.0010 - val_loss: 9.1029e-04
# Epoch 257/300
# 160/160 [==============================] - 0s 757us/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 258/300
# 160/160 [==============================] - 0s 837us/step - loss: 0.0011 - val_loss: 9.7562e-04
# Epoch 259/300
# 160/160 [==============================] - 0s 791us/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 260/300
# 160/160 [==============================] - 0s 755us/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 261/300
# 160/160 [==============================] - 0s 760us/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 262/300
# 160/160 [==============================] - 0s 736us/step - loss: 0.0010 - val_loss: 8.6536e-04
# Epoch 263/300
# 160/160 [==============================] - 0s 761us/step - loss: 0.0010 - val_loss: 9.2482e-04
# Epoch 264/300
# 160/160 [==============================] - 0s 742us/step - loss: 0.0011 - val_loss: 9.4571e-04
# Epoch 265/300
# 160/160 [==============================] - 0s 736us/step - loss: 0.0010 - val_loss: 9.3177e-04
# Epoch 266/300
# 160/160 [==============================] - 0s 760us/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 267/300
# 160/160 [==============================] - 0s 753us/step - loss: 0.0010 - val_loss: 9.7738e-04
# Epoch 268/300
# 160/160 [==============================] - 0s 741us/step - loss: 9.9897e-04 - val_loss: 9.7856e-04
# Epoch 269/300
# 160/160 [==============================] - 0s 739us/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 270/300
# 160/160 [==============================] - 0s 847us/step - loss: 0.0010 - val_loss: 8.5278e-04
# Epoch 271/300
# 160/160 [==============================] - 0s 796us/step - loss: 0.0010 - val_loss: 8.8465e-04
# Epoch 272/300
# 160/160 [==============================] - 0s 762us/step - loss: 0.0010 - val_loss: 9.1663e-04
# Epoch 273/300
# 160/160 [==============================] - 0s 770us/step - loss: 0.0010 - val_loss: 9.8983e-04
# Epoch 274/300
# 160/160 [==============================] - 0s 753us/step - loss: 0.0010 - val_loss: 8.4608e-04
# Epoch 275/300
# 160/160 [==============================] - 0s 794us/step - loss: 9.7755e-04 - val_loss: 0.0010
# Epoch 276/300
# 160/160 [==============================] - 0s 781us/step - loss: 9.5727e-04 - val_loss: 8.9894e-04
# Epoch 277/300
# 160/160 [==============================] - 0s 759us/step - loss: 9.7883e-04 - val_loss: 9.6310e-04
# Epoch 278/300
# 160/160 [==============================] - 0s 758us/step - loss: 9.7922e-04 - val_loss: 8.5339e-04
# Epoch 279/300
# 160/160 [==============================] - 0s 755us/step - loss: 9.8680e-04 - val_loss: 9.0267e-04
# Epoch 280/300
# 160/160 [==============================] - 0s 737us/step - loss: 0.0010 - val_loss: 8.2605e-04
# Epoch 281/300
# 160/160 [==============================] - 0s 919us/step - loss: 9.9370e-04 - val_loss: 8.9874e-04
# Epoch 282/300
# 160/160 [==============================] - 0s 881us/step - loss: 9.8162e-04 - val_loss: 9.5274e-04
# Epoch 283/300
# 160/160 [==============================] - 0s 787us/step - loss: 9.7039e-04 - val_loss: 0.0011
# Epoch 284/300
# 160/160 [==============================] - 0s 829us/step - loss: 9.8814e-04 - val_loss: 0.0010
# Epoch 285/300
# 160/160 [==============================] - 0s 760us/step - loss: 9.7456e-04 - val_loss: 8.4324e-04
# Epoch 286/300
# 160/160 [==============================] - 0s 819us/step - loss: 9.4314e-04 - val_loss: 0.0011
# Epoch 287/300
# 160/160 [==============================] - 0s 790us/step - loss: 9.8392e-04 - val_loss: 8.4552e-04
# Epoch 288/300
# 160/160 [==============================] - 0s 1ms/step - loss: 9.7096e-04 - val_loss: 9.7522e-04
# Epoch 289/300
# 160/160 [==============================] - 0s 801us/step - loss: 9.5177e-04 - val_loss: 8.3494e-04
# Epoch 290/300
# 160/160 [==============================] - 0s 747us/step - loss: 9.4304e-04 - val_loss: 9.3750e-04
# Epoch 291/300
# 160/160 [==============================] - 0s 745us/step - loss: 9.5587e-04 - val_loss: 0.0011
# Epoch 292/300
# 160/160 [==============================] - 0s 797us/step - loss: 9.6440e-04 - val_loss: 7.8672e-04
# Epoch 293/300
# 160/160 [==============================] - 0s 890us/step - loss: 9.5254e-04 - val_loss: 8.6879e-04
# Epoch 294/300
# 160/160 [==============================] - 0s 801us/step - loss: 9.6796e-04 - val_loss: 9.7231e-04
# Epoch 295/300
# 160/160 [==============================] - 0s 862us/step - loss: 9.2975e-04 - val_loss: 8.6148e-04
# Epoch 296/300
# 160/160 [==============================] - 0s 885us/step - loss: 9.4442e-04 - val_loss: 8.0005e-04
# Epoch 297/300
# 160/160 [==============================] - 0s 951us/step - loss: 9.2301e-04 - val_loss: 9.5087e-04
# Epoch 298/300
# 160/160 [==============================] - 0s 915us/step - loss: 9.0868e-04 - val_loss: 0.0010
# Epoch 299/300
# 160/160 [==============================] - 0s 942us/step - loss: 9.1960e-04 - val_loss: 8.9825e-04
# Epoch 300/300
# 160/160 [==============================] - 0s 1ms/step - loss: 9.1420e-04 - val_loss: 8.9752e-04

# %%
weights = DropModel.get_weights() # returs a numpy list of weights

# %%
Wmat = np.array(weights)
# Out:
# /Users/adbonzanini/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.

# %%
def predictive_model_resnet(zk,Wmat): 
    #Assuming you can pass extra arguments to the function for casadi, otherwsise
    #Number of hidden layers and nodes are given once when we get the optimal resnet
    #The Bayesian Optimization Loop will be changing 
    n_hidden_layers = 3
    n_nodes = 5
    model_input = zk.reshape(1,5)
    Wmat_shape = Wmat.shape[0]
    
    #Initialize from input 
    sum0 = np.matmul(zk,Wmat[0]) #Matrix multiplication weights*inputs
    sumbias0 = sum0 + Wmat[1] #Add bias to construct y = sum(wi*xi) + b
    #neuron_out = swish_eval(sum1bias)
    neuron_out = sumbias0/(1+np.exp(-sumbias0)) #explicitly writing swish activation, out = fact(y)
    #They are vector quantitites so you might need to change stuff a bit with symbolic vars
    print(neuron_out.shape)

    #Forward prediction in hidden layers
    for k in range(n_hidden_layers-1):
        sum0 = np.matmul(neuron_out,Wmat[2*k+2])
        sumbias0 = sum0 + Wmat[2*k+3]
        neuron_out = sumbias0/(1+np.exp(-sumbias0)) #explicitly writing swish activation

    #Final output layer with linear activation
    sum0 = np.matmul(neuron_out,Wmat[Wmat_shape-2])
    sumbias0 = sum0 + Wmat[Wmat_shape-1]
    neuron_out = sumbias0  #linear activation

    return neuron_out #+ model_input[0,2:5]

def plantDynamics(matlabEngine, xAll, z):
    # Define the parameters whose scope is limited to this function
    p1 = 82.3
    p2 = 1.0
    p3 = 0.9
    
    # Convert np arrays to list and then to matlab.double
    xMatlab = matlab.double(xAll.tolist())
    zMatlab = [matlab.double([z[0,0]]), matlab.double([z[0,1]])]
    
    # Call the BCR_Discrete function and convert it to np.array since it is matlab type intially
    xNext = np.array(matlabEngine.BCR_Discrete(xMatlab, zMatlab[0], zMatlab[1], p1, p2, p3))
    
    return xNext

# %%
zk=Zin[0,:].reshape(1,5)

# %%
zkplusone  = predictive_model_resnet(zk,Wmat)
# Out:
# (1, 5)

# %%
zk[0,0]
# Out:
# 0.11050563422067754

# %%
print('Current State:', zk,'Future State', zkplusone)
# Out:
# Current State: [[0.11050563 0.6529952  0.3        0.         0.        ]] Future State [[3.01075990e-01 7.23974785e-04 9.25735487e-05]]

# %%
initial_cond_plant =scipy.io.loadmat('init_cond.mat')

# %%
xo = initial_cond_plant.get("yo")

# %%
xo.shape
# Out:
# (1, 87)

# %%
x0 = xo[0,-3:]

# %% [markdown]
# For BCR_Discrete you must convert the states array to a list like below and then put it into matlab.double; \
# Same for matlab.double for the scalars \
# The other, fixed parameters are ok like that

# %%
zkplusone_plant = eng.BCR_Discrete(matlab.double(xo.tolist()),matlab.double([zk[0,0]]),matlab.double([zk[0,1]]),82.3,1.0,0.9)
zkfuture_plant = np.array(zkplusone_plant)
print(zkfuture_plant[0,-3:]) #Getting the last states

# %%
zz = plantDynamics(eng, xo, zk)
print(zz[0,-3:])
# Out:
# [0.29738612 0.01965556 0.00653503]
# [0.29738612 0.01965556 0.00653503]

# %%
zkfuture_plant  = predictive_model_resnet(np.array([zk[0,0],zk[0,1],x0[0],x0[1],x0[2]]),Wmat)
# Out:
# (5,)

# %%
zkfuture_plant
# Out:
# array([3.01075990e-01, 7.23974785e-04, 9.25735487e-05])

# %% [markdown]
# One of the issues here with the zkfuture_plant

# %% [markdown]
# When you are at the initial condition, or acetate and ethanol are very low, usually you will predict negative concentrations for acetate and ethanol. In other words, you will predict x[1], and x[2] <0 which is unphysical. In this case you can make the prediction equal to zero (because otherwise you might not get feasible solutions)

# %% [markdown]
# #Objective Function
# Area = 0.002436;   % reactor cross-sectional area, m^2 \
# L = 1.06;   % reactor length, m  \
# Qmedia[j] = Area \times L \times Dk[j]  (Dk is u[0], i.e., dilution rate) \
# Try to maximize sum (Qmedia[j]*x1[j] ) (m3/h * mmol/m^3)  \
# Constraints:
# Selectivity is defined as Ce/Ca or x2/x1 and I want it to be x2/x1 < 0.45 \
# u[0] in (0.01, 0.25) \
# u[1] in (0.0, 0.9) \
# x0,x1,x2 > 0
